# %% [markdown]
# <a href="https://colab.research.google.com/github/Mutsu1030/clone-test/blob/main/section_2/python_basic_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pythonの基礎2
# リストや分岐、ループなどについて学んでいきます。

# %% [markdown]
# ## ●リスト
# **リスト**は、複数の値をまとめて扱う場合に使用します。
# リストは全体を`[]`で囲み、各要素は`,`で区切ります。

# %%
a = [2011, 2012, 2013, 2014, 2015]  # リストの作成

print(a[0])  # 先頭から0番目の要素
print(a[1])  # 先頭から1番目の要素
print(a[2])  # 先頭から2番目の要素

# %%
# 練習用
a = [2011, 2012, 2013, 2014, 2015]

print(a[0])     # 添え字は、0から始まる！
print(a[1])
print(a[2])
# Out:
# 2011
# 2012
# 2013

# %% [markdown]
# リストでは、変数名の直後に`[ ]`を記述することで各要素を取り出すことができます。
# Pythonのリストはどのような値でも格納することができます。

# %%
b = 2016
c = [b, 2017, 20.1, "Hello", "Hi"]
print(c[1:4])  # 先頭から1番目以上、4番目未満の範囲

# %%
# 練習用
b = 2016
c = [b, 2017, 20.1, "Hello", "Hi"]
print(c[1:4])    # 範囲を指定して取り出す
# Out:
# [2017, 20.1, 'Hello']

# %% [markdown]
# リストの中にリストを格納することもできます。

# %%
d =[[2012, 2013, 2014], [2015, 2016, 2017]]
print(d[0])  # 先頭から0番目の要素

# %%
# 練習用
d = [[2012, 2013, 2014],[2015, 2016, 2017]]
print(d[0])  # 先頭から0番目の要素

print(d[1][2])  # 先頭から1番目の要素の中の2番目　　2017
# Out:
# [2012, 2013, 2014]
# 2017

# %% [markdown]
# リストは、作成後に要素を変更することができます。
# また、appendにより要素を追加することができます。

# %%
e = ["Py", 543.21, 79, "thon", [2018, 2019, 2020]]
print(e)

# 要素の変更
e[2] = 99
print(e)

# 要素の追加
e.append(2021)
print(e)

# %%
# 練習用
e = ["Py", 543.21, 79, "thon", [2018, 2019, 2020]]
print(e)

# 要素の変更
e[2] = 99      # 79→99
print(e)

# 要素の追加
e.append(2021)  #  ["Py", 543.21, 99, "thon", [2018, 2019, 2020], 2021]
print(e)

# e[2]に要素を追加
e.insert(2,200)  # ["Py", 543.21, 200, 99, "thon", [2018, 2019, 2020], 2021]
print(e)

# e[5][1]を2025に変更
e[5][1]=2025
print(e)
# Out:
# ['Py', 543.21, 79, 'thon', [2018, 2019, 2020]]
# ['Py', 543.21, 99, 'thon', [2018, 2019, 2020]]
# ['Py', 543.21, 99, 'thon', [2018, 2019, 2020], 2021]
# ['Py', 543.21, 200, 99, 'thon', [2018, 2019, 2020], 2021]
# ['Py', 543.21, 200, 99, 'thon', [2018, 2025, 2020], 2021]

# %% [markdown]
# リストにより、多くの値を効率よく扱うことが可能になります。

# %% [markdown]
# ## ●タプル
# **タプル**はリストと同じく複数の値をまとめて扱いたいときに利用しますが、要素の追加や削除、入れ替えなどはできません。
# タプルは全体を`()`で囲み、各要素は`,`で区切ります。
# 要素を変更する予定が無い場合は、リストよりもタプルを使用する方がベターです。
# 以下では、リストとタプルを比較しています。

# %%
a = [2012, 2013, 2014]  # リスト
b = (2012, 2013, 2014)  # タプル

print(a)
print(b)

print(a[1])
print(b[1])

a[1] = 2016
print(a)

# b[1] = 2016  # エラーが発生
# print(b)

a.append(2015)
print(a)

# b.append(2015)  # エラーが発生
# print(b)

# %%
# 練習用　　タプル：  要素を変更される心配がいらない
a = [2012, 2013, 2014]  # リスト
b = (2012, 2013, 2014)  # タプル

print(a)
print(b)

print(a[1])
print(b[1])  # 添え字を指定した取り出しはできる

a[1] = 2016
print(a)

# b[1] = 2016   タプルは、変更できない
# print(b)

a.append(2015)
print(a)

# b.append(2015)   タプルは、追加できない
# print(b)
# Out:
# [2012, 2013, 2014]
# (2012, 2013, 2014)
# 2013
# 2013
# [2012, 2016, 2014]
# [2012, 2016, 2014, 2015]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-164/3324141363.py in <cell line: 0>()
#      18 print(a)
#      19
# ---> 20 b.append(2015)
#      21 print(b)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# タプルの要素を変更したり、タプルに要素を追加しようとするとエラーが発生します。

# %% [markdown]
# ## ●辞書
# **辞書**は、キーと値の組合せでデータを格納します。
# 以下は、Pythonの辞書を扱う例です。
# 文字列をキーとして辞書を作成し、値の取得や入れ替え、要素の追加を行なっています。

# %%
a = {"Taro":1985, "Hanako":1986}  # 辞書の作成
print(a["Taro"])   # "Taro"のキーを持つ値を取得

a["Hanako"] = 1987  # 要素の入れ替え
print(a)

a["Jiro"] = 1989  # 要素の追加
print(a)

# %%
# 練習用
a = {"太郎":1985, "花子":1986}  #　辞書の作成
print(a["太郎"])  # キーを指定する

a["花子"] = 1987
print(a)

a["次郎"] = 1989  # 辞書の追加
print(a)
# Out:
# 1985
# {'太郎': 1985, '花子': 1987}
# {'太郎': 1985, '花子': 1987, '次郎': 1989}

# %% [markdown]
# 辞書は、キーを使って多数の値を管理したい際に使用します。

# %% [markdown]
# ## ●if文
# **if**文により条件分岐を行うことができます。
# ifの右側が`True`であればその次の処理が、`False`であればelseの次の処理が実行されます。
# 以下のコードは、`a`の値が5であれば足し算を行い、5でなければ掛け算を行います。

# %%
a = 5

if a == 5:  # aと5は等しいのでifの右はTrue
    print("3+4=")
    print(3+4)
else:
    print("3×4=")
    print(3*4)

# %%
# 練習用

# %% [markdown]
# 分岐後の処理の行頭には、複数のスペースからなる「インデント」を挿入します。
# インデントは通常半角スペース4つを使用します。
#
# 3つ以上の分岐を行う際には、`elif`を使用します。

# %%
b = 4

if b < 3:
    print("Hello!")
elif b < 5:  # ifの右側がFalseの場合
    print("Hi!")
else:  # if、elifの右側がFalseの場合
    print("Yeah!")

# %%
# 練習用

# %% [markdown]
# `elif`を並べることで、さらに多くの分岐を行うことが可能になります。

# %%
time = 20

if time < 12:
    print("Good morning!")
elif time < 17:
    print("Good afternoon!")
elif time < 21:
    print("Good evening!")
else:
    print("Good night!")

# %%
# 練習用

# %% [markdown]
# ## ●for文
# **for**文を使えば、同じ処理を繰り返し実行することができます。
# 以下の例は、リストをとfor文を使ったループ処理です。

# %%
a = [2001, 2002, 2003, 2004, 2005]
for i in a:  # iにはリストaの各要素が入る
    print(i + 10)  # 行頭にインデントを入れる

# %%
# 練習用

# %% [markdown]
# 繰り返し行う処理には行頭にインデントを挿入します。
#
# ループ内で連番の整数を使う場合は、`range`を使用します。
# 以下の例では、`i`に0から5までの整数が入ります。

# %%
for i in range(0, 6):  # iには0以上6未満の整数が入る
    print(i * 2)

# %%
# 練習用

# %% [markdown]
# for文によるループを使うことで、冗長なコードを簡潔にまとめることが可能になります。

# %% [markdown]
# ## ●while文
# ある条件が満たされている間ループするためには、**while**文を用います。

# %%
print("--- 10未満 ---")
a = 0
while a < 10:  # aが10未満である間ループ
    print(a)
    a += 1  # aに1を加える

print("--- 10と等しくない ---")
b = 0
while b != 10:  # bが10と等しくない限りループ
    print(b)
    b += 1

# %%
# 練習用

# %% [markdown]
# ## ●分岐とループの組み合わせ
# 分岐とループを組み合わせることで、条件が満たされた処理のみをループ内で実行することが可能になります。

# %%
a = []  # 空のリスト
for i in range(0, 10):
    if i%2 == 0:  # 偶数であれば
        a.append(i)

print (a)

# %%
# 練習用
